# %%
import pandas as pd

# %%
df = pd.read_csv('/content/penguins_size.csv')

# %%
lt = pd.read_csv('/content/penguins_lter.csv')

# %%
lt.head(2)

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen              39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen              39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen              40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen              40.3  ...              195.0       3250.0  FEMALE
# 4  Adelie  Torgersen              36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
h1 = df.dropna()

# %%
h1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df = df.fillna(method = 'ffill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.shape
# Out:
# (344, 7)

# %%
df.describe(include = 'all')
# Out:
#        species  island  culmen_length_mm  ...  flipper_length_mm  body_mass_g   sex
# count      344     344         344.00000  ...         344.000000   344.000000   344
# unique       3       3               NaN  ...                NaN          NaN     3
# top     Adelie  Biscoe               NaN  ...                NaN          NaN  MALE
# freq       152     168               NaN  ...                NaN          NaN   176
# mean       NaN     NaN          43.92093  ...         200.936047  4201.090116   NaN
# std        NaN     NaN           5.45003  ...          14.042064   802.213531   NaN
# min        NaN     NaN          32.10000  ...         172.000000  2700.000000   NaN
# 25%        NaN     NaN          39.27500  ...         190.000000  3550.000000   NaN
# 50%        NaN     NaN          44.45000  ...         197.000000  4050.000000   NaN
# 75%        NaN     NaN          48.50000  ...         213.250000  4756.250000   NaN
# max        NaN     NaN          59.60000  ...         231.000000  6300.000000   NaN
#
# [11 rows x 7 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue= 'species', size = 3, diag_kind = 'hist')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (7,4))
sns.heatmap(df.corr(), annot = True, cmap = 'cubehelix_r')
plt.show()

# %%
df = df.drop(['island', 'sex'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   culmen_length_mm   344 non-null    float64
#  2   culmen_depth_mm    344 non-null    float64
#  3   flipper_length_mm  344 non-null    float64
#  4   body_mass_g        344 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 13.6+ KB

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size= 0.3)

# %%
print(train.shape)
print(test.shape)
# Out:
# (240, 5)
# (104, 5)

# %%
train_y = train['species']
test_y = test['species']
train_x = train.drop(['species'], axis = 1)
test_x = test.drop(['species'], axis = 1)

# %%
train_x.head(2)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 60               35.7             16.9              185.0       3150.0
# 317              46.9             14.6              222.0       4875.0

# %%
train_y
# Out:
# 60     Adelie
# 317    Gentoo
# 8      Adelie
# 43     Adelie
# 226    Gentoo
#         ...
# 56     Adelie
# 0      Adelie
# 25     Adelie
# 92     Adelie
# 340    Gentoo
# Name: species, Length: 240, dtype: object

# %%
from sklearn import svm
from sklearn import metricsZ
model = svm.SVC()
model.fit(train_x, train_y)
predict = model.predict(test_x)

# %%
metrics.accuracy_score(predict, test_y)
# Out:
# 0.7596153846153846

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter = 10000)
model.fit(train_x, train_y)
predict = model.predict(test_x)

# %%
metrics.accuracy_score(predict, test_y)
# Out:
# 0.9903846153846154
